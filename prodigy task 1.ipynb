# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("data-school-workforce-in-england.csv")

# %%
df
# Out:
#      index location location_code geographic_level  time_period        gender  \
# 0        0  England     E92000001          country       201011        Female
# 1        1  England     E92000001          country       201011        Female
# 2        2  England     E92000001          country       201011        Female
# 3        3  England     E92000001          country       201011        Female
# 4        4  England     E92000001          country       201011          Male
# ..     ...      ...           ...              ...          ...           ...
# 155    155  England     E92000001          country       201920         Total
# 156    156  England     E92000001          country       201920  Unclassified
# 157    157  England     E92000001          country       201920  Unclassified
# 158    158  England     E92000001          country       201920  Unclassified
# 159    159  England     E92000001          country       201920  Unclassified
#
#                     school_type                      grade age_category  \
# 0    Total state-funded schools         Classroom teachers        Total
# 1    Total state-funded schools              Head teachers        Total
# 2    Total state-funded schools  Other Leadership teachers        Total
# 3    Total state-funded schools                      Total        Total
# 4    Total state-funded schools         Classroom teachers        Total
# ..                          ...                        ...          ...
# 155  Total state-funded schools                      Total        Total
# 156  Total state-funded schools         Classroom teachers        Total
# 157  Total state-funded schools              Head teachers        Total
# 158  Total state-funded schools  Other Leadership teachers        Total
# 159  Total state-funded schools                      Total        Total
#
#     average_mean
# 0        34174.7
# 1        60289.8
# 2        49442.5
# 3        36366.9
# 4          35494
# ..           ...
# 155        40537
# 156        34244
# 157      63910.4
# 158      53403.1
# 159      36962.3
#
# [160 rows x 10 columns]

# %%
df.head()
# Out:
#    index location location_code geographic_level  time_period  gender  \
# 0      0  England     E92000001          country       201011  Female
# 1      1  England     E92000001          country       201011  Female
# 2      2  England     E92000001          country       201011  Female
# 3      3  England     E92000001          country       201011  Female
# 4      4  England     E92000001          country       201011    Male
#
#                   school_type                      grade age_category  \
# 0  Total state-funded schools         Classroom teachers        Total
# 1  Total state-funded schools              Head teachers        Total
# 2  Total state-funded schools  Other Leadership teachers        Total
# 3  Total state-funded schools                      Total        Total
# 4  Total state-funded schools         Classroom teachers        Total
#
#   average_mean
# 0      34174.7
# 1      60289.8
# 2      49442.5
# 3      36366.9
# 4        35494

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             160 non-null    int64
#  1   location          160 non-null    object
#  2   location_code     160 non-null    object
#  3   geographic_level  160 non-null    object
#  4   time_period       160 non-null    int64
#  5   gender            160 non-null    object
#  6   school_type       160 non-null    object
#  7   grade             160 non-null    object
#  8   age_category      160 non-null    object
#  9   average_mean      160 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 12.6+ KB

# %%
df.isna().sum()
# Out:
# index               0
# location            0
# location_code       0
# geographic_level    0
# time_period         0
# gender              0
# school_type         0
# grade               0
# age_category        0
# average_mean        0
# dtype: int64

# %%
df.describe()
# Out:
#             index    time_period
# count  160.000000     160.000000
# mean    79.500000  201465.500000
# std     46.332134     291.011249
# min      0.000000  201011.000000
# 25%     39.750000  201213.000000
# 50%     79.500000  201465.500000
# 75%    119.250000  201718.000000
# max    159.000000  201920.000000

# %%
df.gender
# Out:
# 0            Female
# 1            Female
# 2            Female
# 3            Female
# 4              Male
#            ...
# 155           Total
# 156    Unclassified
# 157    Unclassified
# 158    Unclassified
# 159    Unclassified
# Name: gender, Length: 160, dtype: object

# %%
gender_counts = df['gender'].value_counts()

# %%
gender_counts
# Out:
# gender
# Female          40
# Male            40
# Total           40
# Unclassified    40
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar', color='skyblue')
plt.ylabel('age_category')
plt.title('Distribution of Genders in a Population')
plt.show()
